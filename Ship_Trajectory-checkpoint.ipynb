# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
file_path='D:\Internship\AIS_Data\AIS_2022_01_01.csv'
df=pd.read_csv(file_path)
df
# Out:
#               MMSI         BaseDateTime       LAT        LON  SOG    COG  \
# 0        368084090  2022-01-01T00:00:00  29.93174  -89.99243  6.0  296.2
# 1        368140160  2022-01-01T00:00:00  30.33475  -87.14429  0.0  312.0
# 2        366941830  2022-01-01T00:00:02  29.30919  -94.79702  0.0  180.2
# 3        316005971  2022-01-01T00:00:06  46.50268  -84.35674  2.4  258.6
# 4        316004054  2022-01-01T00:00:07  46.50326  -84.37506  0.3   61.9
# ...            ...                  ...       ...        ...  ...    ...
# 7239753  372188000  2022-01-01T23:20:44  13.46062  144.66641  0.0   45.2
# 7239754  372188000  2022-01-01T23:23:44  13.46062  144.66645  0.1   57.6
# 7239755  372188000  2022-01-01T23:29:44  13.46063  144.66643  0.1   47.7
# 7239756  372188000  2022-01-01T23:50:44  13.46065  144.66642  0.0  232.8
# 7239757  367391180  2022-01-01T16:32:16  13.46111  144.66403  0.0  190.0
#
#          Heading       VesselName         IMO CallSign  VesselType  Status  \
# 0          299.0  LARRY B WHIPPLE         NaN  WDK7401        57.0    12.0
# 1           87.0    TWISTED ANGEL  IMO0000000  WDL5339        36.0     NaN
# 2          511.0     SAN PATRICIO         NaN  WCX6675        31.0     5.0
# 3          257.0      BEVERLY M I  IMO9084047  CFP2004        31.0     0.0
# 4          511.0       ADANAC III  IMO8745333     VCLT        31.0     0.0
# ...          ...              ...         ...      ...         ...     ...
# 7239753    322.0     DANCEWOOD SW  IMO9639672    3FGQ2        70.0     5.0
# 7239754    322.0     DANCEWOOD SW  IMO9639672    3FGQ2        70.0     5.0
# 7239755    322.0     DANCEWOOD SW  IMO9639672    3FGQ2        70.0     5.0
# 7239756    322.0     DANCEWOOD SW  IMO9639672    3FGQ2        70.0     5.0
# 7239757     46.0     TUG TALOFOFO  IMO8005680  WDE7273        52.0    15.0
#
#          Length  Width  Draft  Cargo TransceiverClass
# 0          23.0   10.0    3.0   57.0                A
# 1          12.0    7.0    NaN    NaN                B
# 2          18.0    7.0    NaN   57.0                A
# 3          34.0   10.0    5.3   99.0                A
# 4          24.0    5.0    3.0   50.0                A
# ...         ...    ...    ...    ...              ...
# 7239753   170.0   27.0    9.7   70.0                A
# 7239754   170.0   27.0    9.7   70.0                A
# 7239755   170.0   27.0    9.7   70.0                A
# 7239756   170.0   27.0    9.7   70.0                A
# 7239757    32.0   10.0    2.0   52.0                A
#
# [7239758 rows x 17 columns]

# %%
#sort by MMSI
df.sort_values(by="MMSI")
# Out:
#                MMSI         BaseDateTime       LAT        LON  SOG    COG  \
# 6674950           0  2022-01-01T23:37:53  22.21441  -97.86972  0.0  186.7
# 2328532           1  2022-01-01T08:20:34  26.05738  -80.12843  0.0   76.5
# 6857886           1  2022-01-01T14:20:54  30.17609  -89.72594  0.0  360.0
# 5617385           1  2022-01-01T20:59:34  26.05755  -80.12843  0.0  335.8
# 6247758           1  2022-01-01T22:29:33  26.05745  -80.12843  0.0  348.5
# ...             ...                  ...       ...        ...  ...    ...
# 4089976  1072211352  2022-01-01T14:31:16  33.61130 -117.92655  0.1  360.0
# 5923557  1072211352  2022-01-01T22:04:18  33.61132 -117.92657  0.0  360.0
# 2397026  1072211352  2022-01-01T08:34:14  33.61134 -117.92655  0.2  360.0
# 1036294  1072211352  2022-01-01T03:40:14  33.61132 -117.92655  0.0  360.0
# 1366464  1072211352  2022-01-01T04:58:13  33.61133 -117.92656  0.0  360.0
#
#          Heading     VesselName         IMO CallSign  VesselType  Status  \
# 6674950    288.0    CGC SPENCER         NaN     NWHE        55.0    15.0
# 2328532    511.0  MISS MARGARET  IMO0000000      NaN        37.0     NaN
# 6857886    511.0  MISS MARGARET  IMO0000000      NaN        37.0     0.0
# 5617385    511.0  MISS MARGARET  IMO0000000      NaN        37.0     NaN
# 6247758    511.0  MISS MARGARET  IMO0000000      NaN        37.0     NaN
# ...          ...            ...         ...      ...         ...     ...
# 4089976     45.0      SHAMBHALA  IMO0000000  WDG7537        37.0     NaN
# 5923557     46.0      SHAMBHALA  IMO0000000  WDG7537        37.0     NaN
# 2397026     45.0      SHAMBHALA  IMO0000000  WDG7537        37.0     NaN
# 1036294     46.0      SHAMBHALA  IMO0000000  WDG7537        37.0     NaN
# 1366464     45.0      SHAMBHALA  IMO0000000  WDG7537        37.0     NaN
#
#          Length  Width  Draft  Cargo TransceiverClass
# 6674950    82.0   12.0    4.3   55.0                A
# 2328532    21.0    6.0    0.0    0.0                B
# 6857886    21.0    6.0    1.0   33.0                A
# 5617385    21.0    6.0    1.0   33.0                B
# 6247758    21.0    6.0    1.0   33.0                B
# ...         ...    ...    ...    ...              ...
# 4089976    30.0    6.0    NaN    NaN                B
# 5923557    30.0    6.0    NaN    NaN                B
# 2397026    30.0    6.0    NaN    NaN                B
# 1036294    30.0    6.0    NaN    NaN                B
# 1366464    30.0    6.0    NaN    NaN                B
#
# [7239758 rows x 17 columns]

# %%
#Navigation Status
files_path="D:\\Internship\\AIS_Data\\navstatus.csv"
df_nav=pd.read_csv(files_path)
df_nav
# Out:
#    Status                                      vessel_status
# 0       0                         Under way using its engine
# 1       1                                           Anchored
# 2       2                                  Not under command
# 3       3                     Has restricted maneuverability
# 4       4              Ship draught is limiting its movement
# 5       5  Moored (tied to another object to limit free m...
# 6       6                                            Aground
# 7       7                                 Engaged in fishing
# 8       8                                  Under way sailing
# 9       9  Number reserved for modifying reported status ...
# 10     10  Number reserved for modifying reported status ...
# 11     11                  Power-driven vessel towing astern
# 12     12   Power-driven vessel pushing ahead/towing alon...
# 13     13                            Reserved for future use
# 14     14  Any of the following are active: AIS-SART (Sea...
# 15     15                                Undefined (default)
# 16                                                       NaN

# %%
#convert the nav_status to float and then mergw with the AIS data

df_nav = df_nav.replace(r'^\s*$', np.nan, regex=True)
df_nav = df_nav.astype({'Status':'float'})
df_nav
# Out:
#     Status                                      vessel_status
# 0      0.0                         Under way using its engine
# 1      1.0                                           Anchored
# 2      2.0                                  Not under command
# 3      3.0                     Has restricted maneuverability
# 4      4.0              Ship draught is limiting its movement
# 5      5.0  Moored (tied to another object to limit free m...
# 6      6.0                                            Aground
# 7      7.0                                 Engaged in fishing
# 8      8.0                                  Under way sailing
# 9      9.0  Number reserved for modifying reported status ...
# 10    10.0  Number reserved for modifying reported status ...
# 11    11.0                  Power-driven vessel towing astern
# 12    12.0   Power-driven vessel pushing ahead/towing alon...
# 13    13.0                            Reserved for future use
# 14    14.0  Any of the following are active: AIS-SART (Sea...
# 15    15.0                                Undefined (default)
# 16     NaN                                                NaN

# %%
df=pd.merge(df,df_nav,how='left',on='Status')

df
# Out:
#               MMSI         BaseDateTime       LAT        LON  SOG    COG  \
# 0        368084090  2022-01-01T00:00:00  29.93174  -89.99243  6.0  296.2
# 1        368140160  2022-01-01T00:00:00  30.33475  -87.14429  0.0  312.0
# 2        366941830  2022-01-01T00:00:02  29.30919  -94.79702  0.0  180.2
# 3        316005971  2022-01-01T00:00:06  46.50268  -84.35674  2.4  258.6
# 4        316004054  2022-01-01T00:00:07  46.50326  -84.37506  0.3   61.9
# ...            ...                  ...       ...        ...  ...    ...
# 7239753  372188000  2022-01-01T23:20:44  13.46062  144.66641  0.0   45.2
# 7239754  372188000  2022-01-01T23:23:44  13.46062  144.66645  0.1   57.6
# 7239755  372188000  2022-01-01T23:29:44  13.46063  144.66643  0.1   47.7
# 7239756  372188000  2022-01-01T23:50:44  13.46065  144.66642  0.0  232.8
# 7239757  367391180  2022-01-01T16:32:16  13.46111  144.66403  0.0  190.0
#
#          Heading       VesselName         IMO CallSign  VesselType  Status  \
# 0          299.0  LARRY B WHIPPLE         NaN  WDK7401        57.0    12.0
# 1           87.0    TWISTED ANGEL  IMO0000000  WDL5339        36.0     NaN
# 2          511.0     SAN PATRICIO         NaN  WCX6675        31.0     5.0
# 3          257.0      BEVERLY M I  IMO9084047  CFP2004        31.0     0.0
# 4          511.0       ADANAC III  IMO8745333     VCLT        31.0     0.0
# ...          ...              ...         ...      ...         ...     ...
# 7239753    322.0     DANCEWOOD SW  IMO9639672    3FGQ2        70.0     5.0
# 7239754    322.0     DANCEWOOD SW  IMO9639672    3FGQ2        70.0     5.0
# 7239755    322.0     DANCEWOOD SW  IMO9639672    3FGQ2        70.0     5.0
# 7239756    322.0     DANCEWOOD SW  IMO9639672    3FGQ2        70.0     5.0
# 7239757     46.0     TUG TALOFOFO  IMO8005680  WDE7273        52.0    15.0
#
#          Length  Width  Draft  Cargo TransceiverClass  \
# 0          23.0   10.0    3.0   57.0                A
# 1          12.0    7.0    NaN    NaN                B
# 2          18.0    7.0    NaN   57.0                A
# 3          34.0   10.0    5.3   99.0                A
# 4          24.0    5.0    3.0   50.0                A
# ...         ...    ...    ...    ...              ...
# 7239753   170.0   27.0    9.7   70.0                A
# 7239754   170.0   27.0    9.7   70.0                A
# 7239755   170.0   27.0    9.7   70.0                A
# 7239756   170.0   27.0    9.7   70.0                A
# 7239757    32.0   10.0    2.0   52.0                A
#
#                                              vessel_status
# 0         Power-driven vessel pushing ahead/towing alon...
# 1                                                      NaN
# 2        Moored (tied to another object to limit free m...
# 3                               Under way using its engine
# 4                               Under way using its engine
# ...                                                    ...
# 7239753  Moored (tied to another object to limit free m...
# 7239754  Moored (tied to another object to limit free m...
# 7239755  Moored (tied to another object to limit free m...
# 7239756  Moored (tied to another object to limit free m...
# 7239757                                Undefined (default)
#
# [7239758 rows x 18 columns]

# %%
#the number of times the vessels are Anchored
test1 = df['vessel_status'].str.contains('Anchored').value_counts()
test1
# Out:
# False    5125050
# True      245871
# Name: vessel_status, dtype: int64

# %%
#LOADING PORTS Dataset

# %%
file_path2='D:\Internship\Dataset\data\code-list_csv.csv'
df2=pd.read_csv(file_path2)
df2
# Out:
#        Change Country Location                Name    NameWoDiacritics  \
# 0         NaN      AD      ALV    Andorra la Vella    Andorra la Vella
# 1         NaN      AD      CAN             Canillo             Canillo
# 2         NaN      AD      ENC              Encamp              Encamp
# 3         NaN      AD      ESC  Escaldes-Engordany  Escaldes-Engordany
# 4         NaN      AD      EAC               Escàs               Escas
# ...       ...     ...      ...                 ...                 ...
# 111548    NaN      ZW      STH          Southerton          Southerton
# 111549    NaN      ZW      THJ   Thompson Junction   Thompson Junction
# 111550    NaN      ZW      VFA      Victoria Falls      Victoria Falls
# 111551    NaN      ZW      ZMZ            Zimbabwe            Zimbabwe
# 111552    NaN      ZW      ZVS          Zvishavane          Zvishavane
#
#        Subdivision Status  Function    Date IATA   Coordinates Remarks
# 0              NaN     AI  --34-6--   601.0  NaN  4230N 00131E     NaN
# 1              NaN     RL  --3-----   307.0  NaN  4234N 00135E     NaN
# 2              NaN     RL  --3-----   307.0  NaN  4232N 00134E     NaN
# 3              NaN     RL  --3-----   307.0  NaN  4231N 00133E     NaN
# 4               04     RL  --3-----  1407.0  NaN  4233N 00131E     NaN
# ...            ...    ...       ...     ...  ...           ...     ...
# 111548         NaN     RL  --3-----   201.0  NaN  1751S 03101E     NaN
# 111549         NaN     RL  -23-----   701.0  NaN  1800S 02626E     NaN
# 111550         NaN     AI  ---4----  9501.0  NaN           NaN     NaN
# 111551          MV     RL  1-3-----  1401.0  NaN  2016S 03055E     NaN
# 111552          MI     RL  --3-----  1207.0  NaN  2020S 03002E     NaN
#
# [111553 rows x 12 columns]

# %%
df2.dtypes
US_port=df2.loc[df2['Country']=='US']

US_port
# Out:
#        Change Country Location                 Name     NameWoDiacritics  \
# 89057     NaN      US      AT2  Allentown, Allegany  Allentown, Allegany
# 89058     NaN      US      JIN    Alpine, San Diego    Alpine, San Diego
# 89059     NaN      US      ZJI  Alpine, Los Angeles  Alpine, Los Angeles
# 89060     NaN      US      AGW   Arlington, Houston   Arlington, Houston
# 89061     NaN      US      AT3      Arlington, Knox      Arlington, Knox
# ...       ...     ...      ...                  ...                  ...
# 109890    NaN      US      Z9T          Zitlaltepec          Zitlaltepec
# 109891    NaN      US      ZPS        Zolfo Springs        Zolfo Springs
# 109892    NaN      US      ZUL            Zullinger            Zullinger
# 109893    NaN      US      ZUM             Zumbrota             Zumbrota
# 109894    NaN      US      ZWL               Zwolle               Zwolle
#
#        Subdivision Status  Function    Date IATA   Coordinates Remarks
# 89057           NY     RL  --3-----   607.0  NaN  4205N 07804W     NaN
# 89058           CA     RL  --3-----   901.0  NaN  3250N 11646W     NaN
# 89059           CA     RL  -23--6--   901.0  NaN  3432N 11806W     NaN
# 89060           TN     RQ  --3--6--   607.0  NaN  3619N 08743W     NaN
# 89061           TN     RQ  --3--6--   607.0  NaN  3600N 08357W     NaN
# ...            ...    ...       ...     ...  ...           ...     ...
# 109890          NM     RL  --3-----  1501.0  NaN  1912N 09754W     NaN
# 109891          FL     RL  -----6--   901.0  NaN  2729N 08147W     NaN
# 109892          PA     RL  --3-----  1307.0  NaN  3946N 07737W     NaN
# 109893          MN     RL  1-3--6--   307.0  NaN  4417N 09240W     NaN
# 109894          LA     RL  -23--6--   901.0  NaN  3138N 09339W     NaN
#
# [20838 rows x 12 columns]

# %%
#Locations that have PORTS :
id_ports=US_port[US_port['Function'].str.contains("1")]
id_ports
# Out:
#        Change Country Location                   Name       NameWoDiacritics  \
# 89088     NaN      US      CS6      Coxsackie, Greene      Coxsackie, Greene
# 89089     NaN      US      USB  Curtis Bay, Baltimore  Curtis Bay, Baltimore
# 89094     NaN      US      DOG       Douglas, Allegan       Douglas, Allegan
# 89107     NaN      US      FMW         Fairmont, Will         Fairmont, Will
# 89110     NaN      US      ZFI   Fisher Island, Miami   Fisher Island, Miami
# ...       ...     ...      ...                    ...                    ...
# 109829    NaN      US      ZYH            York Harbor            York Harbor
# 109846    NaN      US      YTW             Youngstown             Youngstown
# 109867    NaN      US      8PR                 Zamora                 Zamora
# 109888    NaN      US      ZR9               Zirconia               Zirconia
# 109893    NaN      US      ZUM               Zumbrota               Zumbrota
#
#        Subdivision Status  Function    Date IATA   Coordinates Remarks
# 89088           NY     RL  123-----   607.0  NaN  4221N 07348W     NaN
# 89089           MD     RL  123-----   601.0  NaN  3913N 07635W     NaN
# 89094           MI     RL  1-3--6--   501.0  NaN  4238N 08612W     NaN
# 89107           IL     RL  123--6--   501.0  NaN  4133N 08803W     NaN
# 89110           FL     RL  1-3-----   607.0  NaN  2546N 08008W     NaN
# ...            ...    ...       ...     ...  ...           ...     ...
# 109829          ME     RL  1-3--6--   307.0  NaN  4308N 07038W     NaN
# 109846          NY     RL  1-3-----   407.0  NaN  4314N 07903W     NaN
# 109867          CA     RL  1-3-----  1401.0  NaN  3847N 12152W     NaN
# 109888          NC     RL  1----6--  1201.0  NaN  3514N 08224W     NaN
# 109893          MN     RL  1-3--6--   307.0  NaN  4417N 09240W     NaN
#
# [1757 rows x 12 columns]

# %%
#b=id_ports['Coordinates'].dtypes
#b
id_ports[['LAT', 'LON']] = id_ports['Coordinates'].str.split(' ', expand=True)
id_ports
# Out:
# C:\Users\saisu\AppData\Local\Temp\ipykernel_19248\4082824808.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_ports[['LAT', 'LON']] = id_ports['Coordinates'].str.split(' ', expand=True)
# C:\Users\saisu\AppData\Local\Temp\ipykernel_19248\4082824808.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_ports[['LAT', 'LON']] = id_ports['Coordinates'].str.split(' ', expand=True)
#        Change Country Location                   Name       NameWoDiacritics  \
# 89088     NaN      US      CS6      Coxsackie, Greene      Coxsackie, Greene
# 89089     NaN      US      USB  Curtis Bay, Baltimore  Curtis Bay, Baltimore
# 89094     NaN      US      DOG       Douglas, Allegan       Douglas, Allegan
# 89107     NaN      US      FMW         Fairmont, Will         Fairmont, Will
# 89110     NaN      US      ZFI   Fisher Island, Miami   Fisher Island, Miami
# ...       ...     ...      ...                    ...                    ...
# 109829    NaN      US      ZYH            York Harbor            York Harbor
# 109846    NaN      US      YTW             Youngstown             Youngstown
# 109867    NaN      US      8PR                 Zamora                 Zamora
# 109888    NaN      US      ZR9               Zirconia               Zirconia
# 109893    NaN      US      ZUM               Zumbrota               Zumbrota
#
#        Subdivision Status  Function    Date IATA   Coordinates Remarks    LAT  \
# 89088           NY     RL  123-----   607.0  NaN  4221N 07348W     NaN  4221N
# 89089           MD     RL  123-----   601.0  NaN  3913N 07635W     NaN  3913N
# 89094           MI     RL  1-3--6--   501.0  NaN  4238N 08612W     NaN  4238N
# 89107           IL     RL  123--6--   501.0  NaN  4133N 08803W     NaN  4133N
# 89110           FL     RL  1-3-----   607.0  NaN  2546N 08008W     NaN  2546N
# ...            ...    ...       ...     ...  ...           ...     ...    ...
# 109829          ME     RL  1-3--6--   307.0  NaN  4308N 07038W     NaN  4308N
# 109846          NY     RL  1-3-----   407.0  NaN  4314N 07903W     NaN  4314N
# 109867          CA     RL  1-3-----  1401.0  NaN  3847N 12152W     NaN  3847N
# 109888          NC     RL  1----6--  1201.0  NaN  3514N 08224W     NaN  3514N
# 109893          MN     RL  1-3--6--   307.0  NaN  4417N 09240W     NaN  4417N
#
#            LON
# 89088   07348W
# 89089   07635W
# 89094   08612W
# 89107   08803W
# 89110   08008W
# ...        ...
# 109829  07038W
# 109846  07903W
# 109867  12152W
# 109888  08224W
# 109893  09240W
#
# [1757 rows x 14 columns]

# %%
id_ports['LAT_DD']=id_ports['LAT'].str[:2]
id_ports['LAT_MM']=id_ports['LAT'].str[2:4]
id_ports['LAT_NS']=id_ports['LAT'].str[-1:]

id_ports['LON_DD']=id_ports['LON'].str[:3]
id_ports['LON_MM']=id_ports['LON'].str[3:5]
id_ports['LON_EW']=id_ports['LON'].str[-1:] 


#Convert to float
id_ports = id_ports.astype({'LAT_DD':'float','LAT_MM':'float','LON_DD':'float','LON_MM':'float'})


# aa=id_ports.max()
# aa
#Convert to degree
id_ports['LAT_DEG']=id_ports['LAT_DD']+(id_ports['LAT_MM']/100 )
id_ports['LON_DEG']=id_ports['LON_DD']+(id_ports['LON_MM']/100 )
id_ports




#convert with proper sign (N/S AND W/E)
#id_ports['LAT_DEG']
# Out:
# C:\Users\saisu\AppData\Local\Temp\ipykernel_19248\3355816322.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_ports['LAT_DD']=id_ports['LAT'].str[:2]
# C:\Users\saisu\AppData\Local\Temp\ipykernel_19248\3355816322.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_ports['LAT_MM']=id_ports['LAT'].str[2:4]
# C:\Users\saisu\AppData\Local\Temp\ipykernel_19248\3355816322.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_ports['LAT_NS']=id_ports['LAT'].str[-1:]
# C:\Users\saisu\AppData\Local\Temp\ipykernel_19248\3355816322.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_ports['LON_DD']=id_ports['LON'].str[:3]
# C:\Users\saisu\AppData\Local\Temp\ipykernel_19248\3355816322.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_ports['LON_MM']=id_ports['LON'].str[3:5]
# C:\Users\saisu\AppData\Local\Temp\ipykernel_19248\3355816322.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_ports['LON_EW']=id_ports['LON'].str[-1:]
#        Change Country Location                   Name       NameWoDiacritics  \
# 89088     NaN      US      CS6      Coxsackie, Greene      Coxsackie, Greene
# 89089     NaN      US      USB  Curtis Bay, Baltimore  Curtis Bay, Baltimore
# 89094     NaN      US      DOG       Douglas, Allegan       Douglas, Allegan
# 89107     NaN      US      FMW         Fairmont, Will         Fairmont, Will
# 89110     NaN      US      ZFI   Fisher Island, Miami   Fisher Island, Miami
# ...       ...     ...      ...                    ...                    ...
# 109829    NaN      US      ZYH            York Harbor            York Harbor
# 109846    NaN      US      YTW             Youngstown             Youngstown
# 109867    NaN      US      8PR                 Zamora                 Zamora
# 109888    NaN      US      ZR9               Zirconia               Zirconia
# 109893    NaN      US      ZUM               Zumbrota               Zumbrota
#
#        Subdivision Status  Function    Date IATA  ...    LAT     LON LAT_DD  \
# 89088           NY     RL  123-----   607.0  NaN  ...  4221N  07348W   42.0
# 89089           MD     RL  123-----   601.0  NaN  ...  3913N  07635W   39.0
# 89094           MI     RL  1-3--6--   501.0  NaN  ...  4238N  08612W   42.0
# 89107           IL     RL  123--6--   501.0  NaN  ...  4133N  08803W   41.0
# 89110           FL     RL  1-3-----   607.0  NaN  ...  2546N  08008W   25.0
# ...            ...    ...       ...     ...  ...  ...    ...     ...    ...
# 109829          ME     RL  1-3--6--   307.0  NaN  ...  4308N  07038W   43.0
# 109846          NY     RL  1-3-----   407.0  NaN  ...  4314N  07903W   43.0
# 109867          CA     RL  1-3-----  1401.0  NaN  ...  3847N  12152W   38.0
# 109888          NC     RL  1----6--  1201.0  NaN  ...  3514N  08224W   35.0
# 109893          MN     RL  1-3--6--   307.0  NaN  ...  4417N  09240W   44.0
#
#        LAT_MM  LAT_NS  LON_DD LON_MM  LON_EW  LAT_DEG LON_DEG
# 89088    21.0       N    73.0   48.0       W    42.21   73.48
# 89089    13.0       N    76.0   35.0       W    39.13   76.35
# 89094    38.0       N    86.0   12.0       W    42.38   86.12
# 89107    33.0       N    88.0    3.0       W    41.33   88.03
# 89110    46.0       N    80.0    8.0       W    25.46   80.08
# ...       ...     ...     ...    ...     ...      ...     ...
# 109829    8.0       N    70.0   38.0       W    43.08   70.38
# 109846   14.0       N    79.0    3.0       W    43.14   79.03
# 109867   47.0       N   121.0   52.0       W    38.47  121.52
# 109888   14.0       N    82.0   24.0       W    35.14   82.24
# 109893   17.0       N    92.0   40.0       W    44.17   92.40
#
# [1757 rows x 22 columns]

# %%
# if "W" in id_ports['LON_EW'].values:
#      id_ports['LON_DEG']= id_ports['LON_DEG']*-1
# else:
#     id_ports['LON_DEG']= id_ports['LON_DEG']

# id_ports['LON_DEG'] = id_ports['LON_EW'].apply( lambda x: id_ports['LON_DEG'] if x=="E" else id_ports['LON_DEG']*-1 )


def condition(x):
    if x=="E":
        return 1
    else:
        return -1

id_ports['LON_DEG'] = id_ports['LON_EW'].apply(condition)*id_ports['LON_DEG']
 
id_ports
# Out:
#        Change Country Location                   Name       NameWoDiacritics  \
# 89088     NaN      US      CS6      Coxsackie, Greene      Coxsackie, Greene
# 89089     NaN      US      USB  Curtis Bay, Baltimore  Curtis Bay, Baltimore
# 89094     NaN      US      DOG       Douglas, Allegan       Douglas, Allegan
# 89107     NaN      US      FMW         Fairmont, Will         Fairmont, Will
# 89110     NaN      US      ZFI   Fisher Island, Miami   Fisher Island, Miami
# ...       ...     ...      ...                    ...                    ...
# 109829    NaN      US      ZYH            York Harbor            York Harbor
# 109846    NaN      US      YTW             Youngstown             Youngstown
# 109867    NaN      US      8PR                 Zamora                 Zamora
# 109888    NaN      US      ZR9               Zirconia               Zirconia
# 109893    NaN      US      ZUM               Zumbrota               Zumbrota
#
#        Subdivision Status  Function    Date IATA  ...    LAT     LON LAT_DD  \
# 89088           NY     RL  123-----   607.0  NaN  ...  4221N  07348W   42.0
# 89089           MD     RL  123-----   601.0  NaN  ...  3913N  07635W   39.0
# 89094           MI     RL  1-3--6--   501.0  NaN  ...  4238N  08612W   42.0
# 89107           IL     RL  123--6--   501.0  NaN  ...  4133N  08803W   41.0
# 89110           FL     RL  1-3-----   607.0  NaN  ...  2546N  08008W   25.0
# ...            ...    ...       ...     ...  ...  ...    ...     ...    ...
# 109829          ME     RL  1-3--6--   307.0  NaN  ...  4308N  07038W   43.0
# 109846          NY     RL  1-3-----   407.0  NaN  ...  4314N  07903W   43.0
# 109867          CA     RL  1-3-----  1401.0  NaN  ...  3847N  12152W   38.0
# 109888          NC     RL  1----6--  1201.0  NaN  ...  3514N  08224W   35.0
# 109893          MN     RL  1-3--6--   307.0  NaN  ...  4417N  09240W   44.0
#
#        LAT_MM  LAT_NS  LON_DD LON_MM  LON_EW  LAT_DEG LON_DEG
# 89088    21.0       N    73.0   48.0       W    42.21  -73.48
# 89089    13.0       N    76.0   35.0       W    39.13  -76.35
# 89094    38.0       N    86.0   12.0       W    42.38  -86.12
# 89107    33.0       N    88.0    3.0       W    41.33  -88.03
# 89110    46.0       N    80.0    8.0       W    25.46  -80.08
# ...       ...     ...     ...    ...     ...      ...     ...
# 109829    8.0       N    70.0   38.0       W    43.08  -70.38
# 109846   14.0       N    79.0    3.0       W    43.14  -79.03
# 109867   47.0       N   121.0   52.0       W    38.47 -121.52
# 109888   14.0       N    82.0   24.0       W    35.14  -82.24
# 109893   17.0       N    92.0   40.0       W    44.17  -92.40
#
# [1757 rows x 22 columns]

# %%
a=id_ports[id_ports['LON_EW']=="E"]
a
# Out:
#       Change Country Location           Name NameWoDiacritics Subdivision  \
# 96182    NaN      US      GBV    Garberville      Garberville          CA
# 96329    NaN      US      TUV  Gertrude Cove    Gertrude Cove          AK
# 98970    NaN      US      KAB  Kiska Harbour    Kiska Harbour          AK
# 98971    NaN      US      KIS   Kiska Island     Kiska Island          AK
#
#       Status  Function    Date IATA  ...    LAT     LON LAT_DD LAT_MM  LAT_NS  \
# 96182     RL  1-3--6--   601.0  NaN  ...  4006N  12348E   40.0    6.0       N
# 96329     RQ  1-------   901.0  NaN  ...  5156N  17727E   51.0   56.0       N
# 98970     RL  1-------  1201.0  NaN  ...  5158N  17734E   51.0   58.0       N
# 98971     RL  1-------   212.0  NaN  ...  5157N  17733E   51.0   57.0       N
#
#        LON_DD LON_MM  LON_EW  LAT_DEG LON_DEG
# 96182   123.0   48.0       E    40.06  123.48
# 96329   177.0   27.0       E    51.56  177.27
# 98970   177.0   34.0       E    51.58  177.34
# 98971   177.0   33.0       E    51.57  177.33
#
# [4 rows x 22 columns]

# %%
df['BaseDateTime'] = pd.to_datetime(df['BaseDateTime'])
aa=df.dtypes
aa
# Out:
# MMSI                         int64
# BaseDateTime        datetime64[ns]
# LAT                        float64
# LON                        float64
# SOG                        float64
# COG                        float64
# Heading                    float64
# VesselName                  object
# IMO                         object
# CallSign                    object
# VesselType                 float64
# Status                     float64
# Length                     float64
# Width                      float64
# Draft                      float64
# Cargo                      float64
# TransceiverClass            object
# vessel_status               object
# dtype: object

# %%
df.describe()[['SOG']]
# Out:
#                 SOG
# count  7.239758e+06
# mean   2.073895e+00
# std    5.928803e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    5.000000e-01
# max    1.023000e+02

# %%
df.isnull().sum(axis = 0)
# Out:
# MMSI                      0
# BaseDateTime              0
# LAT                       0
# LON                       0
# SOG                       0
# COG                       0
# Heading                   0
# VesselName            17546
# IMO                 3199337
# CallSign             893918
# VesselType             1920
# Status              1868837
# Length               449765
# Width               1178976
# Draft               4469706
# Cargo               1866011
# TransceiverClass          0
# vessel_status       1868837
# dtype: int64

# %%
id_ports.dtypes
# Out:
# Change               object
# Country              object
# Location             object
# Name                 object
# NameWoDiacritics     object
# Subdivision          object
# Status               object
# Function             object
# Date                float64
# IATA                 object
# Coordinates          object
# Remarks              object
# LAT                  object
# LON                  object
# LAT_DD              float64
# LAT_MM              float64
# LAT_NS               object
# LON_DD              float64
# LON_MM              float64
# LON_EW               object
# LAT_DEG             float64
# LON_DEG             float64
# dtype: object

# %%
df_nav.dtypes
# Out:
# Status           float64
# vessel_status     object
# dtype: object

# %%
id_ports["LON_EW"].value_counts()
# Out:
# W    1536
# E       4
# Name: LON_EW, dtype: int64
